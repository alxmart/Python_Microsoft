# %%
print("Testando a coisa")
# Out:
# Testando a coisa

# %%
x = 122
if x >= 30:
    print(f"O número {x} é maior ou igual a 30")
else:
    print("Menor do que 30")
# Out:
# O número 122 é maior ou igual a 30
